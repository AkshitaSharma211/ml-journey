# %%
import pandas as pd

# %%
from sklearn.datasets import load_diabetes

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
dataset=load_diabetes()

# %%
dataset
# Out:
# {'data': array([[ 0.03807591,  0.05068012,  0.06169621, ..., -0.00259226,
#           0.01990749, -0.01764613],
#         [-0.00188202, -0.04464164, -0.05147406, ..., -0.03949338,
#          -0.06833155, -0.09220405],
#         [ 0.08529891,  0.05068012,  0.04445121, ..., -0.00259226,
#           0.00286131, -0.02593034],
#         ...,
#         [ 0.04170844,  0.05068012, -0.01590626, ..., -0.01107952,
#          -0.04688253,  0.01549073],
#         [-0.04547248, -0.04464164,  0.03906215, ...,  0.02655962,
#           0.04452873, -0.02593034],
#         [-0.04547248, -0.04464164, -0.0730303 , ..., -0.03949338,
#          -0.00422151,  0.00306441]], shape=(442, 10)),
#  'target': array([151.,  75., 141., 206., 135.,  97., 138.,  63., 110., 310., 101.,
#          69., 179., 185., 118., 171., 166., 144.,  97., 168.,  68.,  49.,
#          68., 245., 184., 202., 137.,  85., 131., 283., 129.,  59., 341.,
#          87.,  65., 102., 265., 276., 252.,  90., 100.,  55.,  61.,  92.,
# ...

# %%
df = pd.DataFrame(dataset.data,columns=dataset.feature_names)
df['target']=dataset.target

# %%
df
# Out:
#           age       sex       bmi        bp        s1        s2        s3  \
# 0    0.038076  0.050680  0.061696  0.021872 -0.044223 -0.034821 -0.043401
# 1   -0.001882 -0.044642 -0.051474 -0.026328 -0.008449 -0.019163  0.074412
# 2    0.085299  0.050680  0.044451 -0.005670 -0.045599 -0.034194 -0.032356
# 3   -0.089063 -0.044642 -0.011595 -0.036656  0.012191  0.024991 -0.036038
# 4    0.005383 -0.044642 -0.036385  0.021872  0.003935  0.015596  0.008142
# ..        ...       ...       ...       ...       ...       ...       ...
# 437  0.041708  0.050680  0.019662  0.059744 -0.005697 -0.002566 -0.028674
# 438 -0.005515  0.050680 -0.015906 -0.067642  0.049341  0.079165 -0.028674
# 439  0.041708  0.050680 -0.015906  0.017293 -0.037344 -0.013840 -0.024993
# 440 -0.045472 -0.044642  0.039062  0.001215  0.016318  0.015283 -0.028674
# 441 -0.045472 -0.044642 -0.073030 -0.081413  0.083740  0.027809  0.173816
#
#            s4        s5        s6  target
# ...

# %%
print(df.shape)
print(df.info())
print(df.describe())
# Out:
# (442, 11)
# <class 'pandas.DataFrame'>
# RangeIndex: 442 entries, 0 to 441
# Data columns (total 11 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   age     442 non-null    float64
#  1   sex     442 non-null    float64
#  2   bmi     442 non-null    float64
#  3   bp      442 non-null    float64
#  4   s1      442 non-null    float64
#  5   s2      442 non-null    float64
#  6   s3      442 non-null    float64
#  7   s4      442 non-null    float64
#  8   s5      442 non-null    float64
#  9   s6      442 non-null    float64
#  10  target  442 non-null    float64
# dtypes: float64(11)
# memory usage: 38.1 KB
# None
#                 age           sex           bmi            bp            s1  \
# count  4.420000e+02  4.420000e+02  4.420000e+02  4.420000e+02  4.420000e+02
# mean  -2.511817e-19  1.230790e-17 -2.245564e-16 -4.797570e-17 -1.381499e-17
# std    4.761905e-02  4.761905e-02  4.761905e-02  4.761905e-02  4.761905e-02
# ...

# %%
print(df.isnull().sum())
# diabetes dataset has no nulls but always check
# Out:
# age       0
# sex       0
# bmi       0
# bp        0
# s1        0
# s2        0
# s3        0
# s4        0
# s5        0
# s6        0
# target    0
# dtype: int64

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(6,4))
plt.hist(df['target'], bins=20, color='steelblue')
plt.title('Target Distribution')
plt.xlabel('Disease Progression Score')
plt.show()

# %%
import seaborn as sns
plt.figure(figsize=(10,8))
sns.heatmap(df.corr(), annot=True, fmt='.2f', cmap='coolwarm')
plt.title('Feature Correlation')
plt.show()

# %%
plt.figure(figsize=(12,6))
df.boxplot()
plt.xticks(rotation=45)
plt.title('Outliers Check')
plt.show()

# %%
X = df.drop('target',axis=1)
Y = dataset['target']

# %%
X
# Out:
#           age       sex       bmi        bp        s1        s2        s3  \
# 0    0.038076  0.050680  0.061696  0.021872 -0.044223 -0.034821 -0.043401
# 1   -0.001882 -0.044642 -0.051474 -0.026328 -0.008449 -0.019163  0.074412
# 2    0.085299  0.050680  0.044451 -0.005670 -0.045599 -0.034194 -0.032356
# 3   -0.089063 -0.044642 -0.011595 -0.036656  0.012191  0.024991 -0.036038
# 4    0.005383 -0.044642 -0.036385  0.021872  0.003935  0.015596  0.008142
# ..        ...       ...       ...       ...       ...       ...       ...
# 437  0.041708  0.050680  0.019662  0.059744 -0.005697 -0.002566 -0.028674
# 438 -0.005515  0.050680 -0.015906 -0.067642  0.049341  0.079165 -0.028674
# 439  0.041708  0.050680 -0.015906  0.017293 -0.037344 -0.013840 -0.024993
# 440 -0.045472 -0.044642  0.039062  0.001215  0.016318  0.015283 -0.028674
# 441 -0.045472 -0.044642 -0.073030 -0.081413  0.083740  0.027809  0.173816
#
#            s4        s5        s6
# 0   -0.002592  0.019907 -0.017646
# ...

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(
    X, Y, test_size=0.30, random_state=42)

# %%
print("Train:", X_train.shape)  
print("Test:", X_test.shape)
# Out:
# Train: (309, 10)
# Test: (133, 10)

# %%
## Standardizing the dataset
from sklearn.preprocessing import StandardScaler
scaler =StandardScaler()

# %%
X_train = scaler.fit_transform(X_train)

# %%
X_test=scaler.transform(X_test)

# %%
from sklearn.linear_model import LinearRegression

from sklearn.model_selection import cross_val_score

# %%
regression=LinearRegression()
regression.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
y_pred=regression.predict(X_test)

# %%
mse=cross_val_score(regression,X_train,y_train,scoring='neg_mean_squared_error',cv=5)
from sklearn.metrics import r2_score
from sklearn.metrics import mean_squared_error

# %%
r2 = r2_score(y_test, y_pred)

# %%
mse = mean_squared_error(y_test, y_pred)
rmse = np.sqrt(mse)

# %%
print(f"R² Score : {r2:.4f}")    # how well model fits
print(f"MSE      : {mse:.4f}")   # average squared error
print(f"RMSE     : {rmse:.4f}")  # in same unit as target
# Out:
# R² Score : 0.4773
# MSE      : 2821.7510
# RMSE     : 53.1202

# %%
import seaborn as sns
sns.displot(y_pred-y_test,kind='kde')

# %%
cv_scores = cross_val_score(
    regression, X_train, y_train,
    scoring='neg_mean_squared_error', cv=5
)

# %%
print(f"CV MSE scores : {cv_scores}")
print(f"CV Mean       : {cv_scores.mean():.4f}")
print(f"CV Std        : {cv_scores.std():.4f}")
# Out:
# CV MSE scores : [-3097.67026247 -3326.50097129 -2828.96412737 -3054.21375091
#  -3531.95904446]
# CV Mean       : -3167.8616
# CV Std        : 241.0094

# %%
print("X_train shape:", X_train.shape)
print("X_test shape:", X_test.shape)
print("y_train shape:", y_train.shape)

# Check how many features you used
print("Features used:", X_train.shape[1])
# Out:
# X_train shape: (309, 10)
# X_test shape: (133, 10)
# y_train shape: (309,)
# Features used: 10

# %%
from sklearn.linear_model import Ridge
from sklearn.metrics import r2_score, mean_squared_error
import numpy as np

# Ridge regression
ridge = Ridge(alpha=1.0)
ridge.fit(X_train, y_train)
y_pred_ridge = ridge.predict(X_test)

r2_ridge = r2_score(y_test, y_pred_ridge)
rmse_ridge = np.sqrt(mean_squared_error(y_test, y_pred_ridge))

print("Ridge R²:", r2_ridge)
print("Ridge RMSE:", rmse_ridge)

# Compare both models
results = pd.DataFrame({
    'Model':    ['Linear Regression', 'Ridge Regression'],
    'R2 Score': [r2_score(y_test, y_pred), r2_ridge],
    'RMSE':     [np.sqrt(mean_squared_error(y_test, y_pred)), rmse_ridge]
})
print(results)
# Out:
# Ridge R²: 0.47761740509278305
# Ridge RMSE: 53.10350286715309
#                Model  R2 Score       RMSE
# 0  Linear Regression  0.477290  53.120156
# 1   Ridge Regression  0.477617  53.103503

# %%
from sklearn.linear_model import Lasso

lasso = Lasso(alpha=0.1)
lasso.fit(X_train, y_train)
y_pred_lasso = lasso.predict(X_test)

print("Lasso R²:", r2_score(y_test, y_pred_lasso))
# Out:
# Lasso R²: 0.47815356922835595
