# %%
### Data Ingestion

# %%
### Document structure
# !pip install langchain langchain-core
from langchain_core.documents import Document
# Out:
# ...
#
# [notice] A new release of pip is available: 26.0.1 -> 26.1.2
# [notice] To update, run: pip install --upgrade pip

# %%
doc=Document(
    page_content="this is the main text content i am using to crreate rag",
    metadata={
        "source":"example.txt",
        "pages":1,
        "author":"Akshita",
        "date_created":"2025-01-01"
    }
    
)
doc
# Out:
# Document(metadata={'source': 'example.txt', 'pages': 1, 'author': 'Akshita', 'date_created': '2025-01-01'}, page_content='this is the main text content i am using to crreate rag')
