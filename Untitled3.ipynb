# %%
# !brew install python@3.12
# !python3.12 -m pip install ydata-profiling
# Out:
# ⠋ JSON API formula.jws.json                          Downloading  32.0MB/-------
# ⠋ JSON API cask.jws.json                             Downloading  15.3MB/-------⠋ JSON API formula.jws.json                          Downloading  32.0MB/-------
# ⠋ JSON API cask.jws.json                             Downloading  15.3MB/-------⠙ JSON API formula.jws.json                          Downloading  32.0MB/-------
# ⠙ JSON API cask.jws.json                             Downloading  15.3MB/-------⠚ JSON API formula.jws.json                          Downloading  32.0MB/-------
# ⠚ JSON API cask.jws.json                             Downloading  15.3MB/-------⠞ JSON API formula.jws.json                          Downloaded   32.0MB/-------
# ⠞ JSON API cask.jws.json                             Downloading  15.3MB/-------✔︎ JSON API formula.jws.json                          Downloaded   32.0MB/ 32.0MB
# ...

# %%
# !/opt/homebrew/bin/python3.12 -m pip install ydata-profiling ipykernel --break-system-packages
# !/opt/homebrew/bin/python3.12 -m ipykernel install --user --name py312
# Out:
# ...
# Installed kernelspec py312 in /Users/akshitasharma/Library/Jupyter/kernels/py312

# %%
from ydata_profiling import ProfileReport
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[12], line 1
# ----> 1 from ydata_profiling import ProfileReport
#       2
#
# ModuleNotFoundError: No module named 'ydata_profiling'

# %%
import seaborn as sns
df=sns.load_dataset('tips')
df.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
profile=ProfileReport(df,explorative=True)
profile.to_file('output.html')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 profile=ProfileReport(df,explorative=True)
#       2 profile.to_file('output.html')
#
# NameError: name 'ProfileReport' is not defined

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 244 entries, 0 to 243
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   total_bill  244 non-null    float64
#  1   tip         244 non-null    float64
#  2   sex         244 non-null    category
#  3   smoker      244 non-null    category
#  4   day         244 non-null    category
#  5   time        244 non-null    category
#  6   size        244 non-null    int64
# dtypes: category(4), float64(2), int64(1)
# memory usage: 7.4 KB
